# %%
import json
import pandas as pd
import re

# %%
class BiographyExtracter:
    def __init__(self):
        self.json_path = "./data/raw/biography.json"
        self.name_nodes = []
        self.name_nodes_path = "./data/processed/name_nodes.json"
        self.other_nodes = []
        self.other_nodes_path = "./data/processed/other_nodes.json"
        self.edges = []
        self.edges_path = "./data/processed/edges.json"
        with open(json_path) as json_file:
            self.data = json.load(json_file)

    def _create_edge(self, src, dst, edge_type='', **kwargs):
        self.edges.append({**{'src': src, 'dst': dst, 'edge_type': edge_type}, **kwargs})

    def _append_other_node_and_edge(self, tag, v, **kwargs):
        entry = {"type": tag, "value": v}
        if entry not in self.other_nodes:
            self.other_nodes.append(entry)
        self._create_edge(self._congress_id, v, tag, **kwargs)

    def _create_other_node_and_edge(self, tag):
        value = self._biography[tag]
        if tag == 'data_de_nascimento':
            value = value.split('-')[0][:3]
        self._append_other_node_and_edge(tag, value)
    
    def _create_comission_nodes_edges(self, tag):
        value = self._biography['comissoes_parlamentares_a_que_pertence']
        for v in value:
            node = v.split('[')[0].strip()
            try:
                match = re.search(r'.*?\[(.*)].*' , v)
                edge_info = match.group(1)
            except AttributeError:
                edge_info = 'membro'
            self._append_other_node_and_edge(tag, node, **{'edge_info': edge_info})

    def _save(self):
        with open(self.name_nodes_path, 'w') as outfile:
            json.dump(self.name_nodes, outfile)
        with open(self.other_nodes_path, 'w') as outfile:
            json.dump(self.other_nodes, outfile)
        with open(self.edges_path, 'w') as outfile:
            json.dump(self.edges, outfile)

    def extract_data(self):
        for entry in self.data:
            # Extract data from entries
            self._congress_id = list(entry.keys())[0]
            self._biography = list(entry.values())[0]
            # Create main/name nodes
            self.name_nodes.append({self._congress_id: self._biography['nome_completo']})
            # Create party nodes
            self._create_other_node_and_edge('partido')
            # Create profession nodes
            self._create_other_node_and_edge('profissao')
            # Create comission nodes
            # try clause needed because some congress people do not belong to any?
            try:
                self._create_comission_nodes_edges('comissoes_parlamentares_a_que_pertence')
            except KeyError:
                pass
            # Create birth decade nodes
            self._create_other_node_and_edge('data_de_nascimento')
            self._save()

# %%
a = BiographyExtracter('../crawler/biography.json')

# %%
a.extract_data()

# %%
a.edges
# Out:
# [{'src': '6906', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '6906', 'dst': 'Engenheira Civil', 'edge_type': 'profissao'},
#  {'src': '6906',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6906',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6906',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6906',
#   'dst': 'Grupo de Trabalho - Prestações por incapacidade, decorrentes de doença ou acidentes de trabalho',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6906',
#   'dst': 'Grupo de Trabalho - Carreira Técnico Superior Diagnóstico e Terapêutica',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6906', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6661', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6661', 'dst': 'Técnico Tributário', 'edge_type': 'profissao'},
#  {'src': '6661',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6661',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6661',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6661',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6661', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '7007', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '7007', 'dst': 'Professora ', 'edge_type': 'profissao'},
#  {'src': '7007',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7007',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7007',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7007',
#   'dst': 'Grupo de Trabalho - Educação Inclusiva',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7007',
#   'dst': 'Grupo de Trabalho - Direitos das Pessoas com Deficiência',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7007', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '5933', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '5933',
#   'dst': 'Atriz e Produtora cultural ',
#   'edge_type': 'profissao'},
#  {'src': '5933',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5933',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '5933',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5933',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5933', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '4147', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '4147',
#   'dst': 'Gestora de Recursos Humanos',
#   'edge_type': 'profissao'},
#  {'src': '4147',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4147',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4147',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4147',
#   'dst': 'Grupo de Trabalho - Prestações por incapacidade, decorrentes de doença ou acidentes de trabalho',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4147',
#   'dst': 'Grupo de Trabalho - Regime de Cedência de Interesse Público',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4147', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '1715', 'dst': 'PCP', 'edge_type': 'partido'},
#  {'src': '1715',
#   'dst': 'Técnico Superior da Administração Local',
#   'edge_type': 'profissao'},
#  {'src': '1715',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1715',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1715',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP;Vice-Presidente'},
#  {'src': '1715',
#   'dst': 'Grupo de Trabalho - PJL - Durabilidade e Garantia - Bens de Consumo',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1715',
#   'dst': 'Grupo de Trabalho - Escrutínio das Iniciativas Europeias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1715', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '1458', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '1458',
#   'dst': 'Técnico de Serviço Social e Cultural',
#   'edge_type': 'profissao'},
#  {'src': '1458',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '1458',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1458',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1458', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '3', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '3', 'dst': 'Professor', 'edge_type': 'profissao'},
#  {'src': '3',
#   'dst': 'C',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'o',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'm',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'i',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 's',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 's',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'ã',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'o',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': '',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'd',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'e',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': '',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'D',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'e',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'f',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'e',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 's',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'a',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': '',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'N',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'a',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'c',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'i',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'o',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'n',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'a',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3',
#   'dst': 'l',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '6549', 'dst': 'PAN', 'edge_type': 'partido'},
#  {'src': '6549', 'dst': 'Psicóloga', 'edge_type': 'profissao'},
#  {'src': '6549',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6549',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6549',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6549',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6549',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6549',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6549',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Parlamento dos Jovens',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Educação Inclusiva',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Acompanhamento Processo de Remoção do Amianto em Edíficios Públicos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Alteração ao Regime da Carreira de Enfermagem',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Carreira Técnico Superior Diagnóstico e Terapêutica',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Grupo de Trabalho - Regime de Cedência de Interesse Público',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6549',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6549', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '7083', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '7083', 'dst': 'Gestor de Ciência', 'edge_type': 'profissao'},
#  {'src': '7083',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7083',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7083', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '4450', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '4450', 'dst': 'Professora', 'edge_type': 'profissao'},
#  {'src': '4450',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4450',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4450',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP;Vice-Presidente'},
#  {'src': '4450',
#   'dst': 'Grupo de Trabalho - Júri do Prémio Direitos Humanos 2020',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4450',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4450', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6905', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '6905', 'dst': 'Advogado', 'edge_type': 'profissao'},
#  {'src': '6905',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6905',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6905',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6905',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6905', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '1030', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '1030', 'dst': 'PROFESSOR UNIVERSITARIO', 'edge_type': 'profissao'},
#  {'src': '1030',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1030',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1030',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1030', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '2010', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '2010', 'dst': 'Gestor ', 'edge_type': 'profissao'},
#  {'src': '2010',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2010',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2010',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2010', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '6834', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6834',
#   'dst': 'Gestora de Clientes Corporate',
#   'edge_type': 'profissao'},
#  {'src': '6834',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6834',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6834', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '5489', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '5489', 'dst': 'Eng.º Civil', 'edge_type': 'profissao'},
#  {'src': '5489',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Presidente'},
#  {'src': '5489',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5489', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '6148', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '6148', 'dst': 'Técnico Superior', 'edge_type': 'profissao'},
#  {'src': '6148',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6148',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6148',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '6148',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6148',
#   'dst': 'Grupo de Trabalho - Valorização de Produtos Agroalimentares em Portugal',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6148', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '6949', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6949',
#   'dst': 'Mestre em Comunicação e Jornalismo',
#   'edge_type': 'profissao'},
#  {'src': '6949',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6949',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6949',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6949', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '2445', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '2445', 'dst': 'Quadro superior', 'edge_type': 'profissao'},
#  {'src': '2445',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2445',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '2445',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2445', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '6861', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6861', 'dst': 'Psicóloga', 'edge_type': 'profissao'},
#  {'src': '6861',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6861',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6861',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6861', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6962', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6962', 'dst': 'assistente tecnica ', 'edge_type': 'profissao'},
#  {'src': '6962',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6962',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6962', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '7128', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '7128', 'dst': 'Advogada', 'edge_type': 'profissao'},
#  {'src': '7128',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7128',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7128',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7128', 'dst': '199', 'edge_type': 'data_de_nascimento'},
#  {'src': '6977', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6977', 'dst': 'Professora', 'edge_type': 'profissao'},
#  {'src': '6977',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6977',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6977', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6049', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6049', 'dst': 'Psicóloga Clínica', 'edge_type': 'profissao'},
#  {'src': '6049',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6049',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6049', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6866', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '6866', 'dst': 'Aposentado', 'edge_type': 'profissao'},
#  {'src': '6866',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6866',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6866',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6866', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '1944', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '1944', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '1944',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1944',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1944',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1944',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1944', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '1655', 'dst': 'CDS-PP', 'edge_type': 'partido'},
#  {'src': '1655', 'dst': 'Advogado', 'edge_type': 'profissao'},
#  {'src': '1655',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1655',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1655',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1655',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1655',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1655',
#   'dst': 'Grupo de Trabalho - Avaliação das Condições de Trabalho das Forças de Segurança',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1655',
#   'dst': 'Grupo de Trabalho - Despenalização da Morte Medicamente Assistida',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1655',
#   'dst': 'Grupo de Trabalho - Júri do Prémio Direitos Humanos 2020',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1655',
#   'dst': 'Subcomissão para a Reinserção Social e Assuntos Prisionais',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1655', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '6956', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6956', 'dst': 'Socióloga', 'edge_type': 'profissao'},
#  {'src': '6956',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6956',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6956',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6956', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '1264', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '1264', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '1264',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Presidente'},
#  {'src': '1264',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1264', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '5749', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '5749', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '5749',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5749',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5749',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5749',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5749',
#   'dst': 'Comissão Eventual de Verificação de Poderes dos Deputados Eleitos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5749',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5749', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '132', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '132', 'dst': 'ECONOMISTA', 'edge_type': 'profissao'},
#  {'src': '132', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '1611', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '1611', 'dst': ' Professor', 'edge_type': 'profissao'},
#  {'src': '1611',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1611',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1611',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1611',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1611', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '5581', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '5581', 'dst': 'Professor', 'edge_type': 'profissao'},
#  {'src': '5581',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '5581',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5581', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '6176', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '6176', 'dst': 'Advogada', 'edge_type': 'profissao'},
#  {'src': '6176',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6176',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6176',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6176',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6176',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6176',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6176',
#   'dst': 'Grupo de Trabalho - Avaliação das Condições de Trabalho das Forças de Segurança',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador '},
#  {'src': '6176',
#   'dst': 'Subcomissão para a Reinserção Social e Assuntos Prisionais',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6176', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '5693', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '5693', 'dst': 'Engenheiro Civil', 'edge_type': 'profissao'},
#  {'src': '5693',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5693',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5693',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5693',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5693',
#   'dst': 'Grupo de Trabalho - Voos Civis Noturnos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador '},
#  {'src': '5693', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '4196', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '4196', 'dst': 'Professora Universitária', 'edge_type': 'profissao'},
#  {'src': '4196',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4196',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4196',
#   'dst': 'Grupo de Trabalho - Avaliação das Condições de Trabalho das Forças de Segurança',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4196',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4196', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6867', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6867',
#   'dst': 'Professora  do Ensino Superior',
#   'edge_type': 'profissao'},
#  {'src': '6867',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6867',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6867',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6867', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '5492', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '5492', 'dst': 'ADVOGADO', 'edge_type': 'profissao'},
#  {'src': '5492', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '2273', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '2273', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '2273',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2273',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2273',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2273',
#   'dst': 'Grupo de Trabalho - Audiências',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2273', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6533', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '6533', 'dst': 'Eng. Agrónomo', 'edge_type': 'profissao'},
#  {'src': '6533',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6533',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6533',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6533',
#   'dst': 'Grupo de Trabalho - Valorização de Produtos Agroalimentares em Portugal',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6533', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '6682', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6682', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '6682',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6682',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6682',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6682',
#   'dst': 'Subcomissão para a Igualdade e Não Discriminação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6682', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '6534', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6534',
#   'dst': 'Aposentado da Autoridade Tributaria',
#   'edge_type': 'profissao'},
#  {'src': '6534',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6534',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6534',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '6534',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6534', 'dst': '194', 'edge_type': 'data_de_nascimento'},
#  {'src': '7034', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '7034', 'dst': 'Advogada', 'edge_type': 'profissao'},
#  {'src': '7034',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7034',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7034', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '5835', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '5835', 'dst': 'Contabilista Certificado', 'edge_type': 'profissao'},
#  {'src': '5835',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5835',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5835',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5835', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '7273', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '7273', 'dst': 'Jurista ', 'edge_type': 'profissao'},
#  {'src': '7273',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7273',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7273',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7273', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '4441', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '4441', 'dst': 'Médico', 'edge_type': 'profissao'},
#  {'src': '4441',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4441',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4441',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4441',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '4441', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '469', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '469',
#   'dst': 'INVESTIGADOR EM FILOSOFIA DAS CIÊNCIAS',
#   'edge_type': 'profissao'},
#  {'src': '469',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '469',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '469',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '469',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '469', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '3945', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '3945', 'dst': 'Advogado', 'edge_type': 'profissao'},
#  {'src': '3945',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3945',
#   'dst': 'Subcomissão para a Reinserção Social e Assuntos Prisionais',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3945', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '1992', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '1992', 'dst': 'Professor', 'edge_type': 'profissao'},
#  {'src': '1992',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1992',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1992',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Presidente'},
#  {'src': '1992', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '629', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '629', 'dst': 'Gestor', 'edge_type': 'profissao'},
#  {'src': '629',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '629',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '629', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '6637', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6637', 'dst': 'Quadro Técnico Bancário', 'edge_type': 'profissao'},
#  {'src': '6637',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6637',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6637',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6637', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '3926', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '3926', 'dst': 'Matemático', 'edge_type': 'profissao'},
#  {'src': '3926',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP;Vice-Presidente'},
#  {'src': '3926',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3926',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '3926',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '3926', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '416', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '416', 'dst': 'Tec. Superior IEFP', 'edge_type': 'profissao'},
#  {'src': '416',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '416',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Presidente'},
#  {'src': '416',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '416', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '1893', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '1893',
#   'dst': 'LICENCIADO EM ENG. CIVIL/INSPECTOR PRINCIPAL DA SEG. SOCIAL',
#   'edge_type': 'profissao'},
#  {'src': '1893',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '1893',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1893', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '4453', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '4453', 'dst': 'Docente universitário ', 'edge_type': 'profissao'},
#  {'src': '4453',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4453',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4453',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4453',
#   'dst': 'Comissão Eventual de Verificação de Poderes dos Deputados Eleitos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4453',
#   'dst': 'Grupo de Trabalho - Registo de Interesses',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador '},
#  {'src': '4453', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '4392', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '4392', 'dst': 'Advogado', 'edge_type': 'profissao'},
#  {'src': '4392',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
# ...
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4022',
#   'dst': 'Grupo de Trabalho - Audiências',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4022', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '4194', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '4194', 'dst': 'jornalista', 'edge_type': 'profissao'},
#  {'src': '4194',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '4194',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '4194', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '1657', 'dst': 'CDS-PP', 'edge_type': 'partido'},
#  {'src': '1657', 'dst': 'Jurista', 'edge_type': 'profissao'},
#  {'src': '1657',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1657',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1657',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1657',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1657',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1657',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '1657',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '1657',
#   'dst': 'Grupo de Trabalho - Escrutínio das Iniciativas Europeias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1657',
#   'dst': 'Grupo de Trabalho - Registo de Interesses',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1657',
#   'dst': 'Grupo de Trabalho - Audiências',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1657', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '456', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '456', 'dst': 'Sociólogo', 'edge_type': 'profissao'},
#  {'src': '456',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '456',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '456',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Vice-Presidente'},
#  {'src': '456',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '456', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '1529', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '1529', 'dst': 'Gestor/Empresário', 'edge_type': 'profissao'},
#  {'src': '1529',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1529',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1529', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '1706', 'dst': 'PSD', 'edge_type': 'partido'},
#  {'src': '1706', 'dst': 'Administrador de Empresas', 'edge_type': 'profissao'},
#  {'src': '1706',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1706',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '1706',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '1706', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '64', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '64', 'dst': 'Economista', 'edge_type': 'profissao'},
#  {'src': '64',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '64',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '64',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '64',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '64', 'dst': '195', 'edge_type': 'data_de_nascimento'},
#  {'src': '2234', 'dst': 'PCP', 'edge_type': 'partido'},
#  {'src': '2234', 'dst': 'Advogado', 'edge_type': 'profissao'},
#  {'src': '2234',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '2234',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP;Vice-Presidente'},
#  {'src': '2234',
#   'dst': 'Grupo de Trabalho - Registo de Interesses',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2234', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '2129', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '2129', 'dst': 'Gestor', 'edge_type': 'profissao'},
#  {'src': '2129',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2129',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2129',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2129',
#   'dst': 'Comissão Eventual de Verificação de Poderes dos Deputados Eleitos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2129', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6785', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6785', 'dst': 'Engenheiro do Ambiente', 'edge_type': 'profissao'},
#  {'src': '6785',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6785',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6785', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '2867', 'dst': 'CDS-PP', 'edge_type': 'partido'},
#  {'src': '2867', 'dst': 'Consultor', 'edge_type': 'profissao'},
#  {'src': '2867',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2867',
#   'dst': 'Comissão de Defesa Nacional',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '2867',
#   'dst': 'Comissão de Economia, Inovação, Obras Públicas e Habitação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '2867',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '2867',
#   'dst': 'Comissão de Cultura e Comunicação',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2867',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2867',
#   'dst': 'Grupo de Trabalho - PJL - Durabilidade e Garantia - Bens de Consumo',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2867',
#   'dst': 'Grupo de Trabalho - Audiências',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2867',
#   'dst': 'Grupo de Trabalho - Voos Civis Noturnos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2867',
#   'dst': 'Grupo de Trabalho - Acompanhamento Processo de Remoção do Amianto em Edíficios Públicos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2867', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '5524', 'dst': 'PCP', 'edge_type': 'partido'},
#  {'src': '5524', 'dst': 'Enfermeiro', 'edge_type': 'profissao'},
#  {'src': '5524',
#   'dst': 'Comissão de Assuntos Europeus',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5524',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '5524',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '5524',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '5524',
#   'dst': 'Grupo de Trabalho - Valorização de Produtos Agroalimentares em Portugal',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '5524', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '6550', 'dst': 'IL', 'edge_type': 'partido'},
#  {'src': '6550', 'dst': 'Economista', 'edge_type': 'profissao'},
#  {'src': '6550',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6550',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6550',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador GP'},
#  {'src': '6550',
#   'dst': 'Grupo de Trabalho - Parlamento dos Jovens',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6550',
#   'dst': 'Grupo de Trabalho - Educação Inclusiva',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6550',
#   'dst': 'Grupo de Trabalho - Despenalização da Morte Medicamente Assistida',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6550', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '7046', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '7046', 'dst': 'Advogada', 'edge_type': 'profissao'},
#  {'src': '7046',
#   'dst': 'Comissão de Assuntos Constitucionais, Direitos, Liberdades e Garantias',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7046',
#   'dst': 'Comissão de Educação, Ciência, Juventude e Desporto',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7046',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7046',
#   'dst': 'Grupo de Trabalho - Parlamento dos Jovens',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '7046',
#   'dst': 'Subcomissão para a Reinserção Social e Assuntos Prisionais',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '7046', 'dst': '199', 'edge_type': 'data_de_nascimento'},
#  {'src': '6914', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6914', 'dst': 'ADVOGADA', 'edge_type': 'profissao'},
#  {'src': '6914',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6914',
#   'dst': 'Comissão de Trabalho e Segurança Social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6914',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6914',
#   'dst': 'Comissão Eventual de Inquérito Parlamentar à atuação do Estado na atribuição de apoios na sequência dos incêndios de 2017 na zona do Pinhal Interior',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6914', 'dst': '198', 'edge_type': 'data_de_nascimento'},
#  {'src': '6546', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '6546', 'dst': 'professor', 'edge_type': 'profissao'},
#  {'src': '6546',
#   'dst': 'Comissão de Negócios Estrangeiros e Comunidades Portuguesas',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6546',
#   'dst': 'Comissão de Administração Pública, Modernização Administrativa, Descentralização e Poder Local',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '6546',
#   'dst': 'Comissão de Transparência e Estatuto dos Deputados',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '6546', 'dst': '197', 'edge_type': 'data_de_nascimento'},
#  {'src': '2885', 'dst': 'PS', 'edge_type': 'partido'},
#  {'src': '2885', 'dst': 'Empresaria', 'edge_type': 'profissao'},
#  {'src': '2885',
#   'dst': 'Comissão de Orçamento e Finanças',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2885',
#   'dst': 'Comissão de Agricultura e Mar',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2885',
#   'dst': 'Comissão de Saúde',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2885',
#   'dst': 'Comissão de Ambiente, Energia e Ordenamento do Território',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'membro'},
#  {'src': '2885',
#   'dst': 'Comissão Eventual para o acompanhamento da aplicação das medidas de resposta à pandemia da doença COVID-19 e do processo de recuperação económica e social',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Suplente'},
#  {'src': '2885',
#   'dst': 'Grupo de Trabalho - Acompanhamento Processo de Remoção do Amianto em Edíficios Públicos',
#   'edge_type': 'comissoes_parlamentares_a_que_pertence',
#   'edge_info': 'Coordenador '},
#  {'src': '2885', 'dst': '196', 'edge_type': 'data_de_nascimento'},
#  {'src': '6063', 'dst': 'BE', 'edge_type': 'partido'},
#  {'src': '6063', 'dst': 'Deputada', 'edge_type': 'profissao'},
#  ...]

# %%
edges = []
names = []
parties = []
professions = []
comissions = []
birth_decades = []
other_nodes = []
for entry in data:
    # Extract data from entries
    congress_id = list(entry.keys())[0]
    biography = list(entry.values())[0]
    # Create main/name nodes
    names.append({congress_id: biography['nome_completo']})
    # Create party nodes
    _create_other_node_and_edge(congress_id, biography, 'partido')
    # Create profession nodes
    _create_other_node_and_edge(congress_id, biography, 'profissao')
    # Create comission nodes
    # try clause needed because some congress people do not belong to any?
    try:
        _create_other_node_and_edge(congress_id, biography, 'comissoes_parlamentares_a_que_pertence')
    except KeyError:
        pass
    # Create birth decade nodes
    _create_other_node_and_edge(congress_id, biography, 'data_de_nascimento')

# %%
extract_data(data)
